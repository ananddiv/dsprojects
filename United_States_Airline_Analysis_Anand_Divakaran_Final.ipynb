# %% [markdown]
# <a href="https://colab.research.google.com/github/ananddiv/dsprojects/blob/main/United_States_Airline_Analysis_Anand_Divakaran_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem Statement:
# According to air travel consumer reports, a large proportion of consumer complaints are
# about frequent flight delays. Of all the complaints received from consumers about airline
# services, 32% were related to cancellations, delays, or other deviations from the airlines’
# schedules.
# Unavoidable delays can be caused by air traffic, no passengers at the airport, weather
# conditions, mechanical issues, passengers coming from delayed connecting flights, security
# clearance, and aircraft preparation.

# %% [markdown]
# Objective:
# The objective of this project is to identify the factors that contribute to avoidable flight delays.
# You are also required to build a model to predict if the flight will be delayed.

# %%
#install additional packages
# !pip install pyjanitor
# Out:
# Collecting pyjanitor
#   Downloading pyjanitor-0.27.0-py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from pyjanitor) (8.4.0)
# Collecting pandas-flavor (from pyjanitor)
#   Downloading pandas_flavor-0.6.0-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.10/dist-packages (from pyjanitor) (1.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pyjanitor) (1.11.4)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.10/dist-packages (from pandas-flavor->pyjanitor) (2.0.3)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from pandas-flavor->pyjanitor) (2023.7.0)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy->pyjanitor) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-flavor->pyjanitor) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-flavor->pyjanitor) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-flavor->pyjanitor) (2024.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from xarray->pandas-flavor->pyjanitor) (24.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-flavor->pyjanitor) (1.16.0)
# Installing collected packages: pandas-flavor, pyjanitor
# Successfully installed pandas-flavor-0.6.0 pyjanitor-0.27.0

# %%
#Import python packages
#Data Processing
import pandas as pd
import missingno as msno
import janitor
import re
from datetime import datetime, date
from imblearn.over_sampling import SMOTE

#Linear Algebra
import numpy as np

#Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

#Statistical Analysis
import scipy.stats as stats

#Webscraping
import requests # for making standard html requests
from bs4 import BeautifulSoup # magical tool for parsing html data

#Feature Engineering
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder

#ML Model
from sklearn.model_selection import train_test_split,cross_validate,cross_val_score,GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import SGDClassifier,LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier
from sklearn.metrics import mean_absolute_error
from xgboost import XGBClassifier

#ML Standradize
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold

#ML Metrics
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,roc_auc_score,f1_score,roc_curve,auc

# %% [markdown]
# # 1. Import and aggregate data
# 1.A Collect information related to flights, airports (e.g., type of airport and elevation), and runways
# (e.g., length_ft, width_ft, surface, and number of runways). Gather all fields you believe might cause
# avoidable delays in one dataset.
# Hint: In this case, you would have to determine the keys to join the tables. A data description will be
# useful.

# %%
#import airport data
airport_data = pd.read_excel('airports.xlsx')
#import runway data
runway_data = pd.read_excel('runways.xlsx')
#import airline data
airline_data = pd.read_excel('Airlines.xlsx')
#import dictionary data
dict_data = pd.read_excel('datadictionary.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#Check at the structure of the aiport data
airport_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73805 entries, 0 to 73804
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 73805 non-null  int64
#  1   ident              73805 non-null  object
#  2   type               73805 non-null  object
#  3   name               73805 non-null  object
#  4   latitude_deg       73805 non-null  float64
#  5   longitude_deg      73805 non-null  float64
#  6   elevation_ft       59683 non-null  float64
#  7   continent          38086 non-null  object
#  8   iso_country        73546 non-null  object
#  9   iso_region         73805 non-null  object
#  10  municipality       68739 non-null  object
#  11  scheduled_service  73805 non-null  object
#  12  gps_code           42996 non-null  object
#  13  iata_code          9160 non-null   object
#  14  local_code         32975 non-null  object
#  15  home_link          3492 non-null   object
#  16  wikipedia_link     10705 non-null  object
#  17  keywords           13951 non-null  object
# dtypes: float64(3), int64(1), object(14)
# memory usage: 10.1+ MB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#Check at the structure of the runway data
runway_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43977 entries, 0 to 43976
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         43977 non-null  int64
#  1   airport_ref                43977 non-null  int64
#  2   airport_ident              43977 non-null  object
#  3   length_ft                  43753 non-null  float64
#  4   width_ft                   41088 non-null  float64
#  5   surface                    43518 non-null  object
#  6   lighted                    43977 non-null  int64
#  7   closed                     43977 non-null  int64
#  8   le_ident                   43793 non-null  object
#  9   le_latitude_deg            15016 non-null  float64
#  10  le_longitude_deg           15000 non-null  float64
#  11  le_elevation_ft            12781 non-null  float64
#  12  le_heading_degT            14624 non-null  float64
#  13  le_displaced_threshold_ft  2883 non-null   float64
#  14  he_ident                   37332 non-null  object
#  15  he_latitude_deg            14971 non-null  float64
#  16  he_longitude_deg           14973 non-null  float64
#  17  he_elevation_ft            12620 non-null  float64
#  18  he_heading_degT            16428 non-null  float64
#  19  he_displaced_threshold_ft  3176 non-null   float64
# dtypes: float64(12), int64(4), object(4)
# memory usage: 6.7+ MB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#Check at the structure of the airline data
airline_data.info()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518556 entries, 0 to 518555
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   id           518556 non-null  int64
#  1   Airline      518556 non-null  object
#  2   Flight       518556 non-null  int64
#  3   AirportFrom  518556 non-null  object
#  4   AirportTo    518556 non-null  object
#  5   DayOfWeek    518556 non-null  int64
#  6   Time         518556 non-null  int64
#  7   Length       518556 non-null  int64
#  8   Delay        518556 non-null  int64
# dtypes: int64(6), object(3)
# memory usage: 35.6+ MB

# %%
#Check the first 5 rows from the airline
airline_data.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    id Airline  Flight AirportFrom AirportTo  DayOfWeek  Time  Length  Delay
# 0   1      CO     269         SFO       IAH          3    15     205      1
# 1   2      US    1558         PHX       CLT          3    15     222      1
# 2   3      AA    2400         LAX       DFW          3    20     165      1
# 3   4      AA    2466         SFO       DFW          3    20     195      1
# 4   5      AS     108         ANC       SEA          3    30     202      0

# %% [markdown]
# Identify the number of runways in the airport from the runway dataset.

# %%
runway_count = runway_data.groupby('airport_ident')[['id']].count().sort_values(by='id',ascending=False).reset_index()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
runway_count.rename(columns={"airport_ident": "ident"},inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Merge the runway_count data frame with the airport_data frame

# %%
airport_df0 = airport_data.merge(runway_count, on='ident', how='left')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airport_df0.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      id_x ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601          11.0       NaN          US      US-PA
# 1     38.704022    -101.473911        3435.0       NaN          US      US-KS
# 2     59.947733    -151.692524         450.0       NaN          US      US-AK
# 3     34.864799     -86.770302         820.0       NaN          US      US-AL
# 4     35.608700     -91.254898         237.0       NaN          US      US-AR
#
#    municipality scheduled_service gps_code iata_code local_code home_link  \
# 0      Bensalem                no      00A       NaN        00A       NaN
# 1         Leoti                no     00AA       NaN       00AA       NaN
# 2  Anchor Point                no     00AK       NaN       00AK       NaN
# 3       Harvest                no     00AL       NaN       00AL       NaN
# 4       Newport                no      NaN       NaN        NaN       NaN
#
#   wikipedia_link keywords  id_y
# 0            NaN      NaN   1.0
# 1            NaN      NaN   NaN
# 2            NaN      NaN   1.0
# 3            NaN      NaN   1.0
# 4            NaN     00AR   1.0

# %%
airport_df0.rename(columns={"id_x": "id","id_y":"runway_count"},inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airport_df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73805 entries, 0 to 73804
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 73805 non-null  int64
#  1   ident              73805 non-null  object
#  2   type               73805 non-null  object
#  3   name               73805 non-null  object
#  4   latitude_deg       73805 non-null  float64
#  5   longitude_deg      73805 non-null  float64
#  6   elevation_ft       59683 non-null  float64
#  7   continent          38086 non-null  object
#  8   iso_country        73546 non-null  object
#  9   iso_region         73805 non-null  object
#  10  municipality       68739 non-null  object
#  11  scheduled_service  73805 non-null  object
#  12  gps_code           42996 non-null  object
#  13  iata_code          9160 non-null   object
#  14  local_code         32975 non-null  object
#  15  home_link          3492 non-null   object
#  16  wikipedia_link     10705 non-null  object
#  17  keywords           13951 non-null  object
#  18  runway_count       37265 non-null  float64
# dtypes: float64(4), int64(1), object(14)
# memory usage: 10.7+ MB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airport_df1 = airport_df0[['iata_code','type','elevation_ft','runway_count']]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airport_df1.dropna(subset=['iata_code'],inplace=True)
airport_df1['iata_code'] = airport_df1['iata_code'].str.strip()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-17-064f3260c8bc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airport_df1.dropna(subset=['iata_code'],inplace=True)
# <ipython-input-17-064f3260c8bc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airport_df1['iata_code'] = airport_df1['iata_code'].str.strip()

# %%
airport_df1[airport_df1['iata_code']=='DFW']
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       iata_code           type  elevation_ft  runway_count
# 34733       DFW  large_airport         607.0           7.0

# %% [markdown]
# 1.B. When it comes to on-time arrivals, different airlines perform differently based on the amount of
# experience they have. The major airlines in this field include US Airways Express (founded in
# 1967), Continental Airlines (founded in 1934), and Express Jet (founded in 1986). Pull such
# information specific to various airlines from the given Wikipedia page link.
# https://en.wikipedia.org/wiki/List_of_airlines_of_the_United_States.
# Hint: Here, you should use web scraping to learn how long an airline has been operating for

# %%
url = "https://en.wikipedia.org/wiki/List_of_airlines_of_the_United_States#State-run_airlines"
response = pd.read_html(url)
list_tables = []
for index in range(0,7):
  table = response[index][['IATA','Founded']]
  df = pd.DataFrame(table)
  list_tables.append(df)
airline_founded = pd.concat(list_tables)
airline_founded.reset_index(inplace=True)
airline_founded.dropna(inplace=True)
airline_founded.drop(columns=['index'],inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airline_founded
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     IATA  Founded
# 0     AS   1932.0
# 1     G4   1997.0
# 2     AA   1926.0
# 3     XP   1987.0
# 4     MX   2018.0
# ..   ...      ...
# 126   KH   1982.0
# 127   5X   1988.0
# 128   UJ   1994.0
# 130   KD   2013.0
# 131   WG   1929.0
#
# [90 rows x 2 columns]

# %%
airline_founded.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   IATA  Founded
# 0   AS   1932.0
# 1   G4   1997.0
# 2   AA   1926.0
# 3   XP   1987.0
# 4   MX   2018.0

# %% [markdown]
# 1.D. The total passenger traffic may also contribute to flight delays. The term hub refers to busy
# commercial airports. Large hubs are airports that account for at least 1 percent of the total
# passenger enplanements in the United States. Airports that account for 0.25 percent to 1
# percent of total passenger enplanements are considered medium hubs. Pull passenger traffic
# data from the Wikipedia page given below using web scraping and collate it in a table.
# https://en.wikipedia.org/wiki/List_of_the_busiest_airports_in_the_United_States

# %%
traffic_url = "https://en.wikipedia.org/wiki/List_of_the_busiest_airports_in_the_United_States"
response = pd.read_html(traffic_url)
list_tables = []
for index in range(1,3):
  table = response[index][['IATA Code','2022[2]']]
  df = pd.DataFrame(table)
  if index == 1:
    df['hub_type'] = 'large hub'
  else:
    df['hub_type'] = 'medium hub'
  list_tables.append(df)
traffic_final = pd.concat(list_tables)
traffic_final.reset_index(inplace=True)
traffic_final.columns
traffic_final.dropna(subset=["IATA Code"],inplace=True)
traffic_final.rename(columns={"IATA Code":"iata_code","2022[2]":"traffic"},inplace=True)
traffic_final['iata_code'] = traffic_final['iata_code'].str.strip()
traffic_final.drop(['index'], axis=1,inplace=True)
traffic_final
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    iata_code   traffic    hub_type
# 0        ATL  45396001   large hub
# 1        DFW  35345138   large hub
# 2        DEN  33773832   large hub
# 3        ORD  33120474   large hub
# 4        LAX  32326616   large hub
# ..       ...       ...         ...
# 60       BOI   2230467  medium hub
# 61       OMA   2204395  medium hub
# 62       MEM   2163692  medium hub
# 63       RIC   4068689  medium hub
# 64       RNO   2132856  medium hub
#
# [65 rows x 3 columns]

# %% [markdown]
# 1.C You should then get all the information gathered so far in one place.

# %%
airport_df1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       iata_code            type  elevation_ft  runway_count
# 231         UTK   small_airport           4.0           1.0
# 465         OCA   small_airport           8.0           1.0
# 630         PQS   small_airport         305.0           1.0
# 709         CSE   small_airport        8980.0           1.0
# 1134        JCY   small_airport        1515.0           1.0
# ...         ...             ...           ...           ...
# 73795       SHE   large_airport         198.0           1.0
# 73796       ZYA          closed        1997.0           NaN
# 73797       YNJ  medium_airport         624.0           1.0
# 73798       YKH  medium_airport           NaN           1.0
# 73803       ZYW          closed           4.0           NaN
#
# [9160 rows x 4 columns]

# %%
traffic_final
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    iata_code   traffic    hub_type
# 0        ATL  45396001   large hub
# 1        DFW  35345138   large hub
# 2        DEN  33773832   large hub
# 3        ORD  33120474   large hub
# 4        LAX  32326616   large hub
# ..       ...       ...         ...
# 60       BOI   2230467  medium hub
# 61       OMA   2204395  medium hub
# 62       MEM   2163692  medium hub
# 63       RIC   4068689  medium hub
# 64       RNO   2132856  medium hub
#
# [65 rows x 3 columns]

# %%
airport_final= airport_df1.merge(traffic_final, on='iata_code', how='left')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airport_final[airport_final['iata_code']=='FAI']
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      iata_code           type  elevation_ft  runway_count  traffic hub_type
# 5809       FAI  large_airport         439.0           4.0      NaN      NaN

# %%
airline_data.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    id Airline  Flight AirportFrom AirportTo  DayOfWeek  Time  Length  Delay
# 0   1      CO     269         SFO       IAH          3    15     205      1
# 1   2      US    1558         PHX       CLT          3    15     222      1
# 2   3      AA    2400         LAX       DFW          3    20     165      1
# 3   4      AA    2466         SFO       DFW          3    20     195      1
# 4   5      AS     108         ANC       SEA          3    30     202      0

# %%
airline_df1= airline_data.merge(airport_final,left_on='AirportFrom', right_on='iata_code', how='left')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airline_df1[airline_df1['AirportFrom']=='FAI']
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             id Airline  Flight AirportFrom AirportTo  DayOfWeek  Time  Length  \
# 20          21      AS     128         FAI       SEA          3    80     206
# 238        240      AS      62         FAI       ANC          3   360      70
# 2304      2386      AS      55         FAI       SCC          3   460      71
# 2637      2723      AS     182         FAI       ANC          3   480      63
# 3538      3650      AS     124         FAI       SEA          3   525     225
# ...        ...     ...     ...         ...       ...        ...   ...     ...
# 510682  531114      AS     184         FAI       ANC          5   720      64
# 514501  535082      AS     188         FAI       ANC          5   945      60
# 516045  536700      AS     190         FAI       ANC          5  1050      62
# 516612  537294      AS      51         FAI       BRW          5  1088      87
# 518419  539230      AS      52         FAI       ANC          5  1340      57
#
#         Delay iata_code           type  elevation_ft  runway_count  traffic  \
# 20          0       FAI  large_airport         439.0           4.0      NaN
# 238         0       FAI  large_airport         439.0           4.0      NaN
# 2304        1       FAI  large_airport         439.0           4.0      NaN
# 2637        0       FAI  large_airport         439.0           4.0      NaN
# 3538        1       FAI  large_airport         439.0           4.0      NaN
# ...       ...       ...            ...           ...           ...      ...
# 510682      0       FAI  large_airport         439.0           4.0      NaN
# 514501      0       FAI  large_airport         439.0           4.0      NaN
# 516045      0       FAI  large_airport         439.0           4.0      NaN
# 516612      1       FAI  large_airport         439.0           4.0      NaN
# 518419      0       FAI  large_airport         439.0           4.0      NaN
#
#        hub_type
# 20          NaN
# 238         NaN
# 2304        NaN
# 2637        NaN
# 3538        NaN
# ...         ...
# 510682      NaN
# 514501      NaN
# 516045      NaN
# 516612      NaN
# 518419      NaN
#
# [329 rows x 15 columns]

# %%
airline_df1.rename(columns={"runway_count":"src_runwaycount","traffic":"src_traffic","type":"src_type","hub_type":"src_hubtype","elevation_ft":"src_elevation","iata_code":"src_iata"},inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airline_df1.info()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518556 entries, 0 to 518555
# Data columns (total 15 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               518556 non-null  int64
#  1   Airline          518556 non-null  object
#  2   Flight           518556 non-null  int64
#  3   AirportFrom      518556 non-null  object
#  4   AirportTo        518556 non-null  object
#  5   DayOfWeek        518556 non-null  int64
#  6   Time             518556 non-null  int64
#  7   Length           518556 non-null  int64
#  8   Delay            518556 non-null  int64
#  9   src_iata         518525 non-null  object
#  10  src_type         518525 non-null  object
#  11  src_elevation    518525 non-null  float64
#  12  src_runwaycount  518525 non-null  float64
#  13  src_traffic      434970 non-null  float64
#  14  src_hubtype      434970 non-null  object
# dtypes: float64(3), int64(6), object(6)
# memory usage: 59.3+ MB

# %%
airline_df1= airline_df1.merge(airport_final,left_on='AirportTo', right_on='iata_code', how='left')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airline_df1.rename(columns={"runway_count":"dest_runwaycount","traffic":"dest_traffic","type":"dest_type","hub_type":"dest_hubtype","elevation_ft":"dest_elevation","iata_code":"dest_iata"},inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airline_df1.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    id Airline  Flight AirportFrom AirportTo  DayOfWeek  Time  Length  Delay  \
# 0   1      CO     269         SFO       IAH          3    15     205      1
# 1   2      US    1558         PHX       CLT          3    15     222      1
# 2   3      AA    2400         LAX       DFW          3    20     165      1
# 3   4      AA    2466         SFO       DFW          3    20     195      1
# 4   5      AS     108         ANC       SEA          3    30     202      0
#
#   src_iata  ... src_elevation  src_runwaycount  src_traffic  src_hubtype  \
# 0      SFO  ...          13.0              4.0   20411420.0    large hub
# 1      PHX  ...        1135.0              3.0   21852586.0    large hub
# 2      LAX  ...         125.0              4.0   32326616.0    large hub
# 3      SFO  ...          13.0              4.0   20411420.0    large hub
# 4      ANC  ...         152.0              3.0    2604308.0   medium hub
#
#   dest_iata      dest_type dest_elevation  dest_runwaycount  dest_traffic  \
# 0       IAH  large_airport           97.0               5.0    19814052.0
# 1       CLT  large_airport          748.0               4.0    23100300.0
# 2       DFW  large_airport          607.0               7.0    35345138.0
# 3       DFW  large_airport          607.0               7.0    35345138.0
# 4       SEA  large_airport          433.0               4.0    22157862.0
#
#    dest_hubtype
# 0     large hub
# 1     large hub
# 2     large hub
# 3     large hub
# 4     large hub
#
# [5 rows x 21 columns]

# %%
airline_df1.info()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518556 entries, 0 to 518555
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                518556 non-null  int64
#  1   Airline           518556 non-null  object
#  2   Flight            518556 non-null  int64
#  3   AirportFrom       518556 non-null  object
#  4   AirportTo         518556 non-null  object
#  5   DayOfWeek         518556 non-null  int64
#  6   Time              518556 non-null  int64
#  7   Length            518556 non-null  int64
#  8   Delay             518556 non-null  int64
#  9   src_iata          518525 non-null  object
#  10  src_type          518525 non-null  object
#  11  src_elevation     518525 non-null  float64
#  12  src_runwaycount   518525 non-null  float64
#  13  src_traffic       434970 non-null  float64
#  14  src_hubtype       434970 non-null  object
#  15  dest_iata         518525 non-null  object
#  16  dest_type         518525 non-null  object
#  17  dest_elevation    518525 non-null  float64
#  18  dest_runwaycount  518525 non-null  float64
#  19  dest_traffic      435020 non-null  float64
#  20  dest_hubtype      435020 non-null  object
# dtypes: float64(6), int64(6), object(9)
# memory usage: 83.1+ MB

# %%
airline_df1= airline_df1.merge(airline_founded,left_on='Airline', right_on='IATA', how='left')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airline_df1.info()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518556 entries, 0 to 518555
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                518556 non-null  int64
#  1   Airline           518556 non-null  object
#  2   Flight            518556 non-null  int64
#  3   AirportFrom       518556 non-null  object
#  4   AirportTo         518556 non-null  object
#  5   DayOfWeek         518556 non-null  int64
#  6   Time              518556 non-null  int64
#  7   Length            518556 non-null  int64
#  8   Delay             518556 non-null  int64
#  9   src_iata          518525 non-null  object
#  10  src_type          518525 non-null  object
#  11  src_elevation     518525 non-null  float64
#  12  src_runwaycount   518525 non-null  float64
#  13  src_traffic       434970 non-null  float64
#  14  src_hubtype       434970 non-null  object
#  15  dest_iata         518525 non-null  object
#  16  dest_type         518525 non-null  object
#  17  dest_elevation    518525 non-null  float64
#  18  dest_runwaycount  518525 non-null  float64
#  19  dest_traffic      435020 non-null  float64
#  20  dest_hubtype      435020 non-null  object
#  21  IATA              434955 non-null  object
#  22  Founded           434955 non-null  float64
# dtypes: float64(7), int64(6), object(10)
# memory usage: 91.0+ MB

# %%
airline_df2 = airline_df1[['Airline','AirportFrom','AirportTo','DayOfWeek','Time','Length','src_type','src_elevation','src_runwaycount','src_traffic','dest_type','dest_elevation','dest_runwaycount','dest_traffic','Founded','Delay']]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airline_final = airline_df2.rename(columns={"Airline":"airline","AirportFrom":"src_airport","AirportTo":"dest_airport","DayOfWeek":"dayofweek","Time":"flight_time","Length":"flight_duration","Founded":"airline_founded","Delay":"delay"})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airline_final.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   airline src_airport dest_airport  dayofweek  flight_time  flight_duration  \
# 0      CO         SFO          IAH          3           15              205
# 1      US         PHX          CLT          3           15              222
# 2      AA         LAX          DFW          3           20              165
# 3      AA         SFO          DFW          3           20              195
# 4      AS         ANC          SEA          3           30              202
#
#         src_type  src_elevation  src_runwaycount  src_traffic      dest_type  \
# 0  large_airport           13.0              4.0   20411420.0  large_airport
# 1  large_airport         1135.0              3.0   21852586.0  large_airport
# 2  large_airport          125.0              4.0   32326616.0  large_airport
# 3  large_airport           13.0              4.0   20411420.0  large_airport
# 4  large_airport          152.0              3.0    2604308.0  large_airport
#
#    dest_elevation  dest_runwaycount  dest_traffic  airline_founded  delay
# 0            97.0               5.0    19814052.0              NaN      1
# 1           748.0               4.0    23100300.0              NaN      1
# 2           607.0               7.0    35345138.0           1926.0      1
# 3           607.0               7.0    35345138.0           1926.0      1
# 4           433.0               4.0    22157862.0           1932.0      0

# %%
airline_final.info()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518556 entries, 0 to 518555
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           518556 non-null  object
#  1   src_airport       518556 non-null  object
#  2   dest_airport      518556 non-null  object
#  3   dayofweek         518556 non-null  int64
#  4   flight_time       518556 non-null  int64
#  5   flight_duration   518556 non-null  int64
#  6   src_type          518525 non-null  object
#  7   src_elevation     518525 non-null  float64
#  8   src_runwaycount   518525 non-null  float64
#  9   src_traffic       434970 non-null  float64
#  10  dest_type         518525 non-null  object
#  11  dest_elevation    518525 non-null  float64
#  12  dest_runwaycount  518525 non-null  float64
#  13  dest_traffic      435020 non-null  float64
#  14  airline_founded   434955 non-null  float64
#  15  delay             518556 non-null  int64
# dtypes: float64(7), int64(4), object(5)
# memory usage: 63.3+ MB

# %%
airline_final.isnull().sum()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# airline                 0
# src_airport             0
# dest_airport            0
# dayofweek               0
# flight_time             0
# flight_duration         0
# src_type               31
# src_elevation          31
# src_runwaycount        31
# src_traffic         83586
# dest_type              31
# dest_elevation         31
# dest_runwaycount       31
# dest_traffic        83536
# airline_founded     83601
# delay                   0
# dtype: int64

# %% [markdown]
# # 2. You should then examine the missing values in each field, perform missing value treatment, and justify your actions.

# %%
airline_final.info()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518556 entries, 0 to 518555
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           518556 non-null  object
#  1   src_airport       518556 non-null  object
#  2   dest_airport      518556 non-null  object
#  3   dayofweek         518556 non-null  int64
#  4   flight_time       518556 non-null  int64
#  5   flight_duration   518556 non-null  int64
#  6   src_type          518525 non-null  object
#  7   src_elevation     518525 non-null  float64
#  8   src_runwaycount   518525 non-null  float64
#  9   src_traffic       434970 non-null  float64
#  10  dest_type         518525 non-null  object
#  11  dest_elevation    518525 non-null  float64
#  12  dest_runwaycount  518525 non-null  float64
#  13  dest_traffic      435020 non-null  float64
#  14  airline_founded   434955 non-null  float64
#  15  delay             518556 non-null  int64
# dtypes: float64(7), int64(4), object(5)
# memory usage: 63.3+ MB

# %%
airline_final.isnull().sum()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# airline                 0
# src_airport             0
# dest_airport            0
# dayofweek               0
# flight_time             0
# flight_duration         0
# src_type               31
# src_elevation          31
# src_runwaycount        31
# src_traffic         83586
# dest_type              31
# dest_elevation         31
# dest_runwaycount       31
# dest_traffic        83536
# airline_founded     83601
# delay                   0
# dtype: int64

# %% [markdown]
# Missing data found for src_type, src_elevation, src_traffic, dest_traffic, airline_founded, dest_type, dest_elevation, dest_runway_count - we may need to use numerical imputaion to resolve these.

# %% [markdown]
# #Use the missing number package to identify the missing data.

# %%
msno.matrix(airline_final)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Axes: >

# %% [markdown]
# Identify missing data using seaborn heatmap

# %%
#identify missing data using seaborn heatmap
sns.heatmap(airline_final.isnull())
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Axes: >

# %% [markdown]
# # Handling missing data - use missing data imputation

# %% [markdown]
# Identify the destination airports for which the elevation, runway count are null.

# %%
airline_final[airline_final['dest_elevation'].isnull()].dest_airport.unique()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['CYS'], dtype=object)

# %% [markdown]
# Identify the source airports for which the elevation, runway count are null.

# %%
airline_final[airline_final['src_elevation'].isnull()].src_airport.unique()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['CYS'], dtype=object)

# %% [markdown]
# The only airport for which the elevation & runway count are null is CYS - Cheyenne Regional Jerry Olson Field. Obtain the elevation and runway count from google and update the data.

# %% [markdown]
# Elevation = 6,160 FT, runway count = 2, airport type = small

# %%
airline_final.loc[(airline_final["dest_airport"] == 'CYS'), "dest_elevation"] =  6160
airline_final.loc[(airline_final["dest_airport"] == 'CYS'), "dest_runwaycount"] =  2
airline_final.loc[(airline_final["dest_airport"] == 'CYS'), "dest_type"] =  "small_airport"

airline_final.loc[(airline_final["src_airport"] == 'CYS'), "src_elevation"] =  6160
airline_final.loc[(airline_final["src_airport"] == 'CYS'), "src_runwaycount"] =  2
airline_final.loc[(airline_final["src_airport"] == 'CYS'), "src_type"] =  "small_airport"
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# #identify the counts of null fields in airline dataset

# %%
airline_final.isnull().sum()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# airline                 0
# src_airport             0
# dest_airport            0
# dayofweek               0
# flight_time             0
# flight_duration         0
# src_type                0
# src_elevation           0
# src_runwaycount         0
# src_traffic         83586
# dest_type               0
# dest_elevation          0
# dest_runwaycount        0
# dest_traffic        83536
# airline_founded     83601
# delay                   0
# dtype: int64

# %%
airline_final[airline_final['airline_founded'].isnull()].airline.unique()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['CO', 'US', 'EV'], dtype=object)

# %% [markdown]
# CO-Continental Airlines is now a part of United Airlines. Update the founded year to that of United Airlines<br>
# US-initially US Airway Express.  There was a US Airways Express, which now has the symbol OH, and the new name is PSA. Update the founded year to that of PSA.<br>
# EV - Expressjet
#
# Obtained the founding year from google.
# US - 1962
# EV - 1987
# CO - 1934

# %%
airline_final.loc[(airline_final["airline"] == 'CO'), "airline_founded"] =  1934
airline_final.loc[(airline_final["airline"] == 'US'), "airline_founded"] =  1962
airline_final.loc[(airline_final["airline"] == 'EV'), "airline_founded"] =  1987
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Check for null values again

# %%
airline_final.isnull().sum()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# airline                 0
# src_airport             0
# dest_airport            0
# dayofweek               0
# flight_time             0
# flight_duration         0
# src_type                0
# src_elevation           0
# src_runwaycount         0
# src_traffic         83586
# dest_type               0
# dest_elevation          0
# dest_runwaycount        0
# dest_traffic        83536
# airline_founded         0
# delay                   0
# dtype: int64

# %% [markdown]
# Identify the airports with null values

# %%
airline_final[airline_final['src_traffic'].isnull()].src_airport.unique()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['FAI', 'BQN', 'PSE', 'BIS', 'IYK', 'GFK', 'GSO', 'LMT', 'DLH',
#        'FAR', 'MFE', 'VPS', 'MAF', 'LWS', 'RST', 'ALB', 'DSM', 'MSN',
#        'PNS', 'BHM', 'LIT', 'SAV', 'ICT', 'ECP', 'DHN', 'MGM', 'CAE',
#        'PWM', 'ACV', 'EKO', 'BTR', 'HRL', 'MYR', 'TUS', 'SBN', 'CAK',
#        'TVC', 'DAY', 'MFR', 'BTV', 'TLH', 'TYS', 'CHA', 'LRD', 'BRO',
#        'CRP', 'LAN', 'PVD', 'FWA', 'OKC', 'ORF', 'AEX', 'SYR', 'SHV',
#        'VLD', 'FAT', 'BZN', 'RDM', 'LFT', 'IPL', 'EAU', 'ERI', 'BUF',
#        'AGS', 'ABI', 'GRR', 'LBB', 'LEX', 'MBS', 'MOD', 'AMA', 'SGF',
#        'AZO', 'ABE', 'SWF', 'BGM', 'AVP', 'FNT', 'GSP', 'ATW', 'ITH',
#        'TUL', 'COS', 'ELP', 'ROC', 'SDF', 'ABY', 'TRI', 'XNA', 'ROA',
#        'MLI', 'LYH', 'EVV', 'HPN', 'FAY', 'EWN', 'CSG', 'GPT', 'MLU',
#        'MOB', 'OAJ', 'CHO', 'ILM', 'BMI', 'JAN', 'CID', 'GRK', 'CRW',
#        'HTS', 'PSC', 'SBP', 'CLD', 'PSP', 'SBA', 'MRY', 'GEG', 'RDD',
#        'PAH', 'CMX', 'SPI', 'EUG', 'CIC', 'PIH', 'SGU', 'COD', 'MHT',
#        'GRB', 'FSD', 'AVL', 'BFL', 'RAP', 'DRO', 'PIA', 'SIT', 'TXK',
#        'SCE', 'MEI', 'MDT', 'FCA', 'KOA', 'PLN', 'PHF', 'GNV', 'HLN',
#        'GJT', 'CPR', 'FSM', 'CMI', 'GTF', 'HDN', 'ITO', 'MTJ', 'HSV',
#        'BTM', 'BIL', 'COU', 'MSO', 'SMX', 'TWF', 'ISP', 'GCC', 'LIH',
#        'LNK', 'DAB', 'MQT', 'LGB', 'CWA', 'LSE', 'ACT', 'MHK', 'MOT',
#        'IDA', 'SUN', 'GTR', 'MLB', 'SRQ', 'JAC', 'ASE', 'LCH', 'JNU',
#        'ROW', 'BQK', 'YUM', 'FLG', 'EGE', 'GUC', 'EYW', 'RKS', 'BGR',
#        'ELM', 'ADQ', 'OTZ', 'OTH', 'STT', 'KTN', 'BET', 'SJT', 'CDC',
#        'CEC', 'SPS', 'SCC', 'STX', 'OME', 'MKG', 'WRG', 'TYR', 'BRW',
#        'GGG', 'PSG', 'YAK', 'CLL', 'SAF', 'CYS', 'LWB', 'CDV', 'FLO',
#        'BLI', 'DBQ', 'TOL', 'PIE', 'ADK', 'BKG', 'ABR', 'TEX', 'MMH',
#        'GUM'], dtype=object)

# %%
print(f"Number of airports missing traffic data:{len(airline_final[airline_final['src_traffic'].isnull()].src_airport.unique())}")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Number of airports missing traffic data:226

# %% [markdown]
# Fill the missing traffic values with the median traffic value.

# %% [markdown]
# Find the median traffic from the traffic data set

# %%
traffic_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   iata_code  65 non-null     object
#  1   traffic    65 non-null     int64
#  2   hub_type   65 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
median_traffic = traffic_final['traffic'].median()
print(f"Median Traffic:{median_traffic}")
# Out:
# Median Traffic:7241882.0
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airline_final.loc[(airline_final.src_traffic.isnull()), "src_traffic"] = median_traffic
airline_final.loc[(airline_final.dest_traffic.isnull()), "dest_traffic"] = median_traffic
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Check for any more null values

# %%
airline_final.isnull().sum()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# airline             0
# src_airport         0
# dest_airport        0
# dayofweek           0
# flight_time         0
# flight_duration     0
# src_type            0
# src_elevation       0
# src_runwaycount     0
# src_traffic         0
# dest_type           0
# dest_elevation      0
# dest_runwaycount    0
# dest_traffic        0
# airline_founded     0
# delay               0
# dtype: int64

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Define a function to calculate the age of the airline.

# %%
def airline_age(year_founded):
  year_now = datetime.now().year
  return (year_now-year_founded)

airline_final['airline_age'] = airline_final['airline_founded'].apply(airline_age)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airline_final.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   airline src_airport dest_airport  dayofweek  flight_time  flight_duration  \
# 0      CO         SFO          IAH          3           15              205
# 1      US         PHX          CLT          3           15              222
# 2      AA         LAX          DFW          3           20              165
# 3      AA         SFO          DFW          3           20              195
# 4      AS         ANC          SEA          3           30              202
#
#         src_type  src_elevation  src_runwaycount  src_traffic      dest_type  \
# 0  large_airport           13.0              4.0   20411420.0  large_airport
# 1  large_airport         1135.0              3.0   21852586.0  large_airport
# 2  large_airport          125.0              4.0   32326616.0  large_airport
# 3  large_airport           13.0              4.0   20411420.0  large_airport
# 4  large_airport          152.0              3.0    2604308.0  large_airport
#
#    dest_elevation  dest_runwaycount  dest_traffic  airline_founded  delay  \
# 0            97.0               5.0    19814052.0           1934.0      1
# 1           748.0               4.0    23100300.0           1962.0      1
# 2           607.0               7.0    35345138.0           1926.0      1
# 3           607.0               7.0    35345138.0           1926.0      1
# 4           433.0               4.0    22157862.0           1932.0      0
#
#    airline_age
# 0         90.0
# 1         62.0
# 2         98.0
# 3         98.0
# 4         92.0

# %% [markdown]
# # 3. Perform data visualization and share your insights on the following points:<br>

# %% [markdown]
# 3a. According to the data provided, approximately 70% of Southwest Airlines flights are delayed. Compare it with other airlines' data by visualizing it.

# %% [markdown]
# Define a function to calculate the total count

# %%
def total_flight(airline):
  return(airline_final[(airline_final["airline"] == airline)]['airline'].count())
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Identify the percentage delay

# %%
airline_delay = airline_final.groupby('airline')['delay'].sum().sort_values(ascending=False).reset_index()
airline_delay.rename(columns={'delay':'total_delayed'},inplace=True)
airline_delay['total_count'] = airline_delay['airline'].apply(total_flight)
airline_delay['percentage_delay'] = round((airline_delay['total_delayed']/airline_delay['total_count'])*100,2)
airline_delay
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    airline  total_delayed  total_count  percentage_delay
# 0       WN          65657        94097             69.78
# 1       DL          27452        60940             45.05
# 2       OO          22760        50254             45.29
# 3       AA          17736        45656             38.85
# 4       MQ          12742        36605             34.81
# 5       CO          11957        21118             56.62
# 6       XE          11795        31126             37.89
# 7       US          11591        34500             33.60
# 8       EV          11255        27983             40.22
# 9       UA           8946        27619             32.39
# 10      B6           8459        18112             46.70
# 11      9E           8226        20686             39.77
# 12      AS           3892        11471             33.93
# 13      OH           3502        12630             27.73
# 14      YV           3334        13725             24.29
# 15      F9           2899         6456             44.90
# 16      HA           1786         5578             32.02

# %% [markdown]
# Plot the delay count vs airline

# %%
plt.figure(figsize=(25,8))
ax = sns.barplot(data=airline_delay,x='airline',y='total_count',errorbar=None)
for i in ax.containers:
    ax.bar_label(i,)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# The dataset is kind of unbalaned by airlines - we have more data for Southwest when compared to other airlines.

# %%
plt.figure(figsize=(15,8))
ax=sns.barplot(data=airline_delay,x='airline',y='percentage_delay',errorbar=None)
for i in ax.containers:
    ax.bar_label(i,)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Maximum number of delays is found for Southwest - WN. 70% of Southwest flights are delayed.

# %% [markdown]
# 3b. Flights were delayed on various weekdays. Which day of the week is the safest for travel?

# %% [markdown]
# Identify the total flight count on each day of the week

# %%
def total_flight1(dayofweek):
  return(airline_final[(airline_final["dayofweek"] == dayofweek)]['dayofweek'].count())
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Calcuate the percentage delay on each day of the week. It is not enough if we count the flight delays but we need to determine what percetage of the flights on a day is delayed.

# %%
weekly_delay = airline_final.groupby('dayofweek')['delay'].sum().sort_values(ascending=False).reset_index()
weekly_delay.rename(columns={'delay':'delay_count'},inplace=True)
weekly_delay['total_count'] = weekly_delay['dayofweek'].apply(total_flight1)
weekly_delay['percentage_delay'] = round((weekly_delay['delay_count']/weekly_delay['total_count'])*100,2)
weekly_delay
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    dayofweek  delay_count  total_count  percentage_delay
# 0          3        41144        86478             47.58
# 1          4        40280        87988             45.78
# 2          5        34813        81797             42.56
# 3          1        33059        70008             47.22
# 4          2        31072        68721             45.21
# 5          7        30761        67210             45.77
# 6          6        22860        56354             40.56

# %% [markdown]
# Plot day of the week against the percentage delay

# %%
plt.figure(figsize=(10,8))
ax=sns.barplot(data=weekly_delay,x='dayofweek',y='percentage_delay',errorbar=None)
for i in ax.containers:
    ax.bar_label(i,)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Friday and Saturday are the days with minumum delays. It is hence best to travel on Friday and Saturdays.

# %% [markdown]
# 3c. Which airlines should be recommended for short, medium, and long-distance travel?

# %%
airline_final.columns
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Index(['airline', 'src_airport', 'dest_airport', 'dayofweek', 'flight_time',
#        'flight_duration', 'src_type', 'src_elevation', 'src_runwaycount',
#        'src_traffic', 'dest_type', 'dest_elevation', 'dest_runwaycount',
#        'dest_traffic', 'airline_founded', 'delay', 'airline_age'],
#       dtype='object')

# %% [markdown]
# Segregate the airline data into 3 bins - short, medium and long route types.

# %%
distance_type_df = airline_final[['airline','flight_duration','delay']]
distance_type_df['duration_type'] = pd.cut(distance_type_df.flight_duration,3,labels=['short','medium','long'])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-70-5521e114b3b1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   distance_type_df['duration_type'] = pd.cut(distance_type_df.flight_duration,3,labels=['short','medium','long'])

# %% [markdown]
# Identify the percentage delay based on the route type

# %%
q= distance_type_df.groupby(['airline','duration_type'])['delay'].count().reset_index()
q['total_delays'] = distance_type_df.groupby(['airline','duration_type'])['delay'].sum().reset_index()['delay']
q['percent_delay'] = (q['total_delays']/q['delay'])*100
q.fillna(0,axis=1,inplace=True)
q.drop(columns=['delay','total_delays'],inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Identify the percentage of delays

# %%
def delay_percent(x):
    return round(x.sum()/x.size*100,2)
duration_grp = distance_type_df.groupby(['airline', 'duration_type'])['delay'].apply(delay_percent).reset_index().pivot(index = 'airline', columns = 'duration_type').fillna(0)['delay']
x = duration_grp.reset_index()
x
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# duration_type airline  short  medium   long
# 0                  9E  39.77    0.00   0.00
# 1                  AA  37.62   43.25  60.40
# 2                  AS  32.58   38.17   0.00
# 3                  B6  45.70   51.05   0.00
# 4                  CO  52.88   64.96  66.87
# 5                  DL  43.88   50.24  48.62
# 6                  EV  40.22   50.00   0.00
# 7                  F9  45.03   43.56   0.00
# 8                  HA  30.16   40.48   0.00
# 9                  MQ  34.82   27.42   0.00
# 10                 OH  27.61   39.20   0.00
# 11                 OO  45.25   53.03   0.00
# 12                 UA  29.92   37.10  39.26
# 13                 US  31.96   40.72   0.00
# 14                 WN  69.12   77.61   0.00
# 15                 XE  37.87   53.70   0.00
# 16                 YV  24.28   25.86   0.00

# %%
#identify the airline for short hauls
best_short_airline = x[x.short == x.short.min()]['airline'].reset_index()
#identify the airline for medium hauls
best_medium_airline = x[x.medium == x.medium.min()]['airline'].reset_index()
#identify the airline for long hauls
best_long_airline = x[x.long == x.long.min()]['airline'].reset_index()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Show the airline with the minumum delays based on the route type.

# %%
print(f"Airline with minumum delays for short flights:{best_short_airline.airline.tolist()[0]}-Mesa")
print(f"Airline with minumum delays for medium flights:{best_medium_airline.airline.tolist()[0]}-Endeavor")
print(f"Airline with minumum delays for long flights:{best_long_airline.airline.tolist()}")
# Out:
# Airline with minumum delays for short flights:YV-Mesa
# Airline with minumum delays for medium flights:9E-Endeavor
# Airline with minumum delays for long flights:['9E', 'AS', 'B6', 'EV', 'F9', 'HA', 'MQ', 'OH', 'OO', 'US', 'WN', 'XE', 'YV']
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Best Short haul flight - Mesa <br>
# Best Meduim haul flight - Endeavor<br>
# Best Long haul flights - Endeavor, Alaska, JetBlue, ExpressJet, Frontier, Hawaiian, Envoy, PSA, Skywest, US Airway Express, Southwest, JSX and Mesa

# %% [markdown]
#  3d. Do you notice any patterns in the departure times of long-duration flights?

# %%
airline_w_distance_type = airline_final.copy()
airline_w_distance_type['duration_type'] = pd.cut(airline_w_distance_type.flight_duration,3,labels=['short','medium','long'])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airline_w_distance_type.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   airline src_airport dest_airport  dayofweek  flight_time  flight_duration  \
# 0      CO         SFO          IAH          3           15              205
# 1      US         PHX          CLT          3           15              222
# 2      AA         LAX          DFW          3           20              165
# 3      AA         SFO          DFW          3           20              195
# 4      AS         ANC          SEA          3           30              202
#
#         src_type  src_elevation  src_runwaycount  src_traffic      dest_type  \
# 0  large_airport           13.0              4.0   20411420.0  large_airport
# 1  large_airport         1135.0              3.0   21852586.0  large_airport
# 2  large_airport          125.0              4.0   32326616.0  large_airport
# 3  large_airport           13.0              4.0   20411420.0  large_airport
# 4  large_airport          152.0              3.0    2604308.0  large_airport
#
#    dest_elevation  dest_runwaycount  dest_traffic  airline_founded  delay  \
# 0            97.0               5.0    19814052.0           1934.0      1
# 1           748.0               4.0    23100300.0           1962.0      1
# 2           607.0               7.0    35345138.0           1926.0      1
# 3           607.0               7.0    35345138.0           1926.0      1
# 4           433.0               4.0    22157862.0           1932.0      0
#
#    airline_age duration_type
# 0         90.0         short
# 1         62.0        medium
# 2         98.0         short
# 3         98.0         short
# 4         92.0         short

# %%
duration_type_data = airline_w_distance_type.loc[airline_w_distance_type.duration_type == 'long'][['flight_time','duration_type']]
duration_type_data.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       flight_time duration_type
# 4232          565          long
# 4772          595          long
# 5738          650          long
# 6104          670          long
# 6477          690          long

# %%
duration_type_data.flight_time.describe()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# count     559.000000
# mean      840.635063
# std       221.020092
# min       540.000000
# 25%       670.000000
# 50%       717.000000
# 75%      1045.000000
# max      1310.000000
# Name: flight_time, dtype: float64

# %% [markdown]
# Average Departure Time - On an average, long haul flights tend to depart at 8.40 AM <br>
# Minumum Departure Time - The first long haul flight departs at 5.40 AM<br>
# Maximum Departure Time - The last long haul flight departs at 1.10 PM <br>
#
# The 25th percentile (first quartile) value of 670 minutes and the 75th percentile (third quartile) value of 1045 minutes indicate that 25% of the long haul flights depart before 6:10 AM (approximately) and 75% of the flights depart before 5:45 PM (approximately).

# %%
plt.hist(duration_type_data.flight_time, bins=12)
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.title('Distribution of Time for Long Flights')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # 4. How many flights were delayed at large hubs compared to medium hubs? Use appropriate visualization to represent your findings.

# %% [markdown]
# Obtain the value counts in airline final dataset for the source types

# %%
airline_final['src_type'].value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# src_type
# large_airport     422594
# medium_airport     94758
# small_airport       1204
# Name: count, dtype: int64

# %% [markdown]
# Flights delayed at different hubtypes

# %%
delay_srchubtype = airline_final.groupby(['src_type'])['delay'].sum().reset_index()
delay_srchubtype
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          src_type   delay
# 0   large_airport  196094
# 1  medium_airport   37531
# 2   small_airport     364

# %%
ax = sns.barplot(data=delay_srchubtype,x='src_type',y='delay',errorbar=None)
#ax.set(xlabel='common xlabel', ylabel='common ylabel')
for i in ax.containers:
    ax.bar_label(i,)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Obtain the value counts in airline final dataset for the destination types

# %%
delay_dsthubtype = airline_final.groupby(['dest_type'])['delay'].sum().reset_index()
delay_dsthubtype
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         dest_type   delay
# 0   large_airport  190311
# 1  medium_airport   43154
# 2   small_airport     524

# %%
ax = sns.barplot(data=delay_dsthubtype,x='dest_type',y='delay',errorbar=None)
#ax.set(xlabel='common xlabel', ylabel='common ylabel')
for i in ax.containers:
    ax.bar_label(i,)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# The number of flights delayed at the large airport is more than that of medum and small airports

# %% [markdown]
# # 5. Use hypothesis testing strategies to discover the below use cases

# %% [markdown]
# 5a.If the airport's altitude has anything to do with flight delays for incoming and departing flights

# %% [markdown]
# H0 - The altitiude of airport has nothing to do with flight delays. (There is no change in the mean delays between both the polulations)<br>
# H1 - The altitude of airport has an impact on the flight delays.  (There is a some change in the mean delays between both the polulations)<br>

# %% [markdown]
# Source Airports

# %%
s1 = airline_final[airline_final['delay'] == 0]['src_elevation']
s2 = airline_final[airline_final['delay'] == 1]['src_elevation']
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
t,p = stats.ttest_ind(s1,s2)
if p <0.05:
  result = "Reject null hypothesis"
else:
  result = "Fail to reject null hypothesis"
print(result)
# Out:
# Reject null hypothesis
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Destination Airports

# %%
s1 = airline_final[airline_final['delay'] == 0]['dest_elevation']
s2 = airline_final[airline_final['delay'] == 1]['dest_elevation']
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
t,p = stats.ttest_ind(s1,s2)
if p <0.05:
  result = "Reject null hypothesis"
else:
  result = "Fail to reject null hypothesis"
print(result)
# Out:
# Reject null hypothesis
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# The elevation of the souurce and destination airports plays an important role in the delay of flights.

# %% [markdown]
# 5b. If the number of runways at an airport affects flight delays

# %% [markdown]
# H0:Number of runways does not pay a role in flight delays<br>
# H1:Number or runways plays a role in the delay of flights

# %% [markdown]
# Source Airports

# %%
s1 = airline_final[airline_final['delay'] == 0]['src_runwaycount']
s2 = airline_final[airline_final['delay'] == 1]['src_runwaycount']
t,p = stats.ttest_ind(s1,s2)
if p <0.05:
  result = "Reject null hypothesis"
else:
  result = "Fail to reject null hypothesis"
print(result)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Reject null hypothesis

# %% [markdown]
# Destination Airports

# %%
s1 = airline_final[airline_final['delay'] == 0]['dest_runwaycount']
s2 = airline_final[airline_final['delay'] == 1]['dest_runwaycount']
t,p = stats.ttest_ind(s1,s2)
if p <0.05:
  result = "Reject null hypothesis"
else:
  result = "Fail to reject null hypothesis"
print(result)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Reject null hypothesis

# %% [markdown]
# Number or runways plays a role in the delay of flights

# %% [markdown]
# 5c.If the duration of a flight (length) affects flight delays

# %% [markdown]
# H0:Duration of flights does not play a role in the flight delays<br>
# H1:Duration of flights play a role in the flight delays

# %%
s1 = airline_final[airline_final['delay'] == 0]['flight_duration']
s2 = airline_final[airline_final['delay'] == 1]['flight_duration']
t,p = stats.ttest_ind(s1,s2)
if p <0.05:
  result = "Reject null hypothesis"
else:
  result = "Fail to reject null hypothesis"
print(result)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Reject null hypothesis

# %% [markdown]
# Duration of flights play a role in the flight delays

# %% [markdown]
# # 6. Find the correlation matrix between the flight delay predictors, create a heatmap to visualize this and share your findings

# %%
airline_final.info()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518556 entries, 0 to 518555
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           518556 non-null  object
#  1   src_airport       518556 non-null  object
#  2   dest_airport      518556 non-null  object
#  3   dayofweek         518556 non-null  int64
#  4   flight_time       518556 non-null  int64
#  5   flight_duration   518556 non-null  int64
#  6   src_type          518556 non-null  object
#  7   src_elevation     518556 non-null  float64
#  8   src_runwaycount   518556 non-null  float64
#  9   src_traffic       518556 non-null  float64
#  10  dest_type         518556 non-null  object
#  11  dest_elevation    518556 non-null  float64
#  12  dest_runwaycount  518556 non-null  float64
#  13  dest_traffic      518556 non-null  float64
#  14  airline_founded   518556 non-null  float64
#  15  delay             518556 non-null  int64
#  16  airline_age       518556 non-null  float64
# dtypes: float64(8), int64(4), object(5)
# memory usage: 67.3+ MB

# %%
airline_df = airline_final.drop(columns=['airline_founded'])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airline_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518556 entries, 0 to 518555
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           518556 non-null  object
#  1   src_airport       518556 non-null  object
#  2   dest_airport      518556 non-null  object
#  3   dayofweek         518556 non-null  int64
#  4   flight_time       518556 non-null  int64
#  5   flight_duration   518556 non-null  int64
#  6   src_type          518556 non-null  object
#  7   src_elevation     518556 non-null  float64
#  8   src_runwaycount   518556 non-null  float64
#  9   src_traffic       518556 non-null  float64
#  10  dest_type         518556 non-null  object
#  11  dest_elevation    518556 non-null  float64
#  12  dest_runwaycount  518556 non-null  float64
#  13  dest_traffic      518556 non-null  float64
#  14  delay             518556 non-null  int64
#  15  airline_age       518556 non-null  float64
# dtypes: float64(7), int64(4), object(5)
# memory usage: 63.3+ MB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airline_num_col = airline_df.select_dtypes(include=['float64','int64']).columns
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airline_df[airline_num_col].corr()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                   dayofweek  flight_time  flight_duration  src_elevation  \
# dayofweek          1.000000     0.001035         0.013222       0.001421
# flight_time        0.001035     1.000000        -0.020844       0.013614
# flight_duration    0.013222    -0.020844         1.000000      -0.090078
# src_elevation      0.001421     0.013614        -0.090078       1.000000
# src_runwaycount   -0.000040     0.091841         0.050654       0.088684
# src_traffic        0.004611     0.120656         0.113605       0.133136
# dest_elevation     0.001239    -0.009837        -0.054747       0.243123
# dest_runwaycount  -0.000412    -0.116307         0.090036      -0.017168
# dest_traffic       0.004322    -0.121161         0.167301      -0.018614
# delay             -0.025481     0.149537         0.040618       0.010678
# airline_age        0.005208    -0.004274         0.337413      -0.023942
#
#                   src_runwaycount  src_traffic  dest_elevation  \
# dayofweek               -0.000040     0.004611        0.001239
# flight_time              0.091841     0.120656       -0.009837
# flight_duration          0.050654     0.113605       -0.054747
# src_elevation            0.088684     0.133136        0.243123
# src_runwaycount          1.000000     0.602732       -0.017924
# src_traffic              0.602732     1.000000       -0.020630
# dest_elevation          -0.017924    -0.020630        1.000000
# dest_runwaycount        -0.215959    -0.231444        0.088561
# dest_traffic            -0.233133    -0.238945        0.133071
# delay                    0.029935     0.014206        0.012130
# airline_age              0.099152     0.178115       -0.023747
#
#                   dest_runwaycount  dest_traffic     delay  airline_age
# dayofweek                -0.000412      0.004322 -0.025481     0.005208
# flight_time              -0.116307     -0.121161  0.149537    -0.004274
# flight_duration           0.090036      0.167301  0.040618     0.337413
# src_elevation            -0.017168     -0.018614  0.010678    -0.023942
# src_runwaycount          -0.215959     -0.233133  0.029935     0.099152
# src_traffic              -0.231444     -0.238945  0.014206     0.178115
# dest_elevation            0.088561      0.133071  0.012130    -0.023747
# dest_runwaycount          1.000000      0.602798 -0.061595     0.098099
# dest_traffic              0.602798      1.000000 -0.054860     0.177506
# delay                    -0.061595     -0.054860  1.000000     0.000044
# airline_age               0.098099      0.177506  0.000044     1.000000

# %%
fig, ax = plt.subplots(figsize=(12,12))

# creating a mask
mask = np.triu(np.ones_like(airline_df[airline_num_col].corr().corr()))

# plotting a triangle correlation heatmap
dataplot = sns.heatmap(airline_df[airline_num_col].corr(), cmap="YlGnBu", annot=True, mask=mask)

plt.title('Correlation Matrix of Flight Delay Predictors')

# displaying heatmap
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Observations:<br>
# 1. Number of runways is positively co-related t the traffic at the airport. <br>
# 2. Flight time is posively corelated to the delay. (this points to the fact that filghts starting at certain time of a day will get delayed normally) <br>
# 3. Delay is negatively co-related with the number of runways in the destination airport<br>
# 4. Dealy is negatively co-related with the triffic in the destination airport.

# %% [markdown]
# High Impact Predictors on Flight Delay

# %% [markdown]
# 1. Flight time <br>
# 2. Flight duration <br>
# 3. Destination runway count <br>
# 4. Destination traffic <br>

# %% [markdown]
# # Machine Learning

# %% [markdown]
# 1. Use OneHotEncoder and OrdinalEncoder to deal with categorical variables

# %%
airline_df.info()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518556 entries, 0 to 518555
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           518556 non-null  object
#  1   src_airport       518556 non-null  object
#  2   dest_airport      518556 non-null  object
#  3   dayofweek         518556 non-null  int64
#  4   flight_time       518556 non-null  int64
#  5   flight_duration   518556 non-null  int64
#  6   src_type          518556 non-null  object
#  7   src_elevation     518556 non-null  float64
#  8   src_runwaycount   518556 non-null  float64
#  9   src_traffic       518556 non-null  float64
#  10  dest_type         518556 non-null  object
#  11  dest_elevation    518556 non-null  float64
#  12  dest_runwaycount  518556 non-null  float64
#  13  dest_traffic      518556 non-null  float64
#  14  delay             518556 non-null  int64
#  15  airline_age       518556 non-null  float64
# dtypes: float64(7), int64(4), object(5)
# memory usage: 63.3+ MB

# %% [markdown]
# Dropping the columns airline, src_airport,dest_airport as these are noise variables.

# %%
airline_ml= airline_df.drop(columns=['airline','src_airport','dest_airport'])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airline_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518556 entries, 0 to 518555
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   dayofweek         518556 non-null  int64
#  1   flight_time       518556 non-null  int64
#  2   flight_duration   518556 non-null  int64
#  3   src_type          518556 non-null  object
#  4   src_elevation     518556 non-null  float64
#  5   src_runwaycount   518556 non-null  float64
#  6   src_traffic       518556 non-null  float64
#  7   dest_type         518556 non-null  object
#  8   dest_elevation    518556 non-null  float64
#  9   dest_runwaycount  518556 non-null  float64
#  10  dest_traffic      518556 non-null  float64
#  11  delay             518556 non-null  int64
#  12  airline_age       518556 non-null  float64
# dtypes: float64(7), int64(4), object(2)
# memory usage: 51.4+ MB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airline_ml['dest_type'].value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# dest_type
# large_airport     422636
# medium_airport     94723
# small_airport       1197
# Name: count, dtype: int64

# %%
#Get the list of categorical variables
s=(airline_ml.dtypes == 'object')
object_cols = list(s[s].index)
print("Categorical variables:")
print(object_cols)
ordinal_encoder = OrdinalEncoder()
airline_ml[object_cols] = ordinal_encoder.fit_transform(airline_ml[object_cols])
#OH_encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)
# Out:
# Categorical variables:
# ['src_type', 'dest_type']
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airline_ml['src_type'].value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# src_type
# 0.0    422594
# 1.0     94758
# 2.0      1204
# Name: count, dtype: int64

# %% [markdown]
# 2. Perform the following model-building steps:

# %% [markdown]
# 2.a Split data into train and test

# %%
#define predictor dataset
X=airline_ml.drop(columns = ['delay'])
#define target dataset
y=airline_ml.delay
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
X.describe()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#            dayofweek    flight_time  flight_duration       src_type  \
# count  518556.000000  518556.000000    518556.000000  518556.000000
# mean        3.927088     801.506969       132.219201       0.187378
# std         1.914558     277.634360        70.926564       0.396121
# min         1.000000      10.000000         0.000000       0.000000
# 25%         2.000000     565.000000        80.000000       0.000000
# 50%         4.000000     795.000000       115.000000       0.000000
# 75%         5.000000    1030.000000       163.000000       0.000000
# max         7.000000    1439.000000       655.000000       2.000000
#
#        src_elevation  src_runwaycount   src_traffic      dest_type  \
# count  518556.000000    518556.000000  5.185560e+05  518556.000000
# mean      895.111610         4.166065  1.747975e+07       0.187284
# std      1375.401963         2.044744  1.219395e+07       0.396012
# min       -54.000000         1.000000  2.132856e+06       0.000000
# 25%        54.000000         3.000000  7.241882e+06       0.000000
# 50%       607.000000         4.000000  1.375120e+07       0.000000
# 75%       958.000000         5.000000  2.548050e+07       0.000000
# max      9070.000000        11.000000  4.539600e+07       2.000000
#
#        dest_elevation  dest_runwaycount  dest_traffic    airline_age
# count   518556.000000     518556.000000  5.185560e+05  518556.000000
# mean       895.270011          4.166717  1.748257e+07      62.228041
# std       1375.672271          2.045860  1.219434e+07      27.716668
# min        -54.000000          1.000000  2.132856e+06       8.000000
# 25%         54.000000          3.000000  7.241882e+06      40.000000
# 50%        607.000000          4.000000  1.375120e+07      57.000000
# 75%        958.000000          5.000000  2.548050e+07      98.000000
# max       9070.000000         11.000000  4.539600e+07     100.000000

# %%
#Split the data into train and test with a test size of 20%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42,test_size=0.2)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Validate the

# %%
print(len(X_train))
print(len(y_train))
print(len(X_test))
print(len(y_test))
# Out:
# 414844
# 414844
# 103712
# 103712
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# 2.b.Standardize data

# %%
#Standardization
sc = StandardScaler()
X_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.transform(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
airline_ml['delay'].value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# delay
# 0    284567
# 1    233989
# Name: count, dtype: int64

# %% [markdown]
# We have an imbalanced sample set for the target varaible and hence we need to do a SMOTE To balance the dataset.

# %%
#Use smote to oversample the
oversample=SMOTE(random_state=42)
X_transformed,y_transformed = oversample.fit_resample(X_scaled,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
y_transformed.value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# delay
# 0    227574
# 1    227574
# Name: count, dtype: int64

# %%
#Define the metrics function
def metrics(y_test, preds):
    print(f'Model Accuracy Score:{accuracy_score(y_test, preds)}')
    print('Model Classification Report')
    print(classification_report(y_test, preds))
    print('Confusion Matrix')
    print(confusion_matrix(y_test, preds))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# 2.c. Apply logistic regression (use stochastic gradient descent optimizer) and decision tree models <br>
# Note: Make sure you use standardization effectively, ensuring no data leakage and leverage
# pipelines to have a cleaner cod

# %% [markdown]
# 2.c.1 Applying Logistic Regression Model

# %%
lrg = LogisticRegression(solver='liblinear',random_state=42)
lrg.fit(X_transformed, y_transformed)
lrg_preds = lrg.predict(X_test)
metrics(y_test,lrg_preds)
lrg_f1 = f1_score(y_test, lrg_preds, average="macro")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Model Accuracy Score:0.5495313946312866
# Model Classification Report
#               precision    recall  f1-score   support
#
#            0       0.55      1.00      0.71     56993
#            1       0.00      0.00      0.00     46719
#
#     accuracy                           0.55    103712
#    macro avg       0.27      0.50      0.35    103712
# weighted avg       0.30      0.55      0.39    103712
#
# Confusion Matrix
# [[56993     0]
#  [46719     0]]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# 2.c.2 Applying Stochastic gradient descent optimizer

# %%
sgd_model = SGDClassifier(loss='log_loss')
sgd_model.fit(X_transformed,y_transformed)
sgd_preds = sgd_model.predict(X_test)
metrics(y_test,sgd_preds)
sgd_f1 = f1_score(y_test, sgd_preds, average="macro")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SGDClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Model Accuracy Score:0.5495313946312866
# Model Classification Report
#               precision    recall  f1-score   support
#
#            0       0.55      1.00      0.71     56993
#            1       0.00      0.00      0.00     46719
#
#     accuracy                           0.55    103712
#    macro avg       0.27      0.50      0.35    103712
# weighted avg       0.30      0.55      0.39    103712
#
# Confusion Matrix
# [[56993     0]
#  [46719     0]]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
#  2.d. Check the accuracy report of the model on the train and test data

# %%
print(f'F1 Score - Logistic Regression:{lrg_f1}')
print(f'F1 Score - Shotastic Gradient Descent:{sgd_f1}')
# Out:
# F1 Score - Logistic Regression:0.3546436016303164
# F1 Score - Shotastic Gradient Descent:0.3546436016303164
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# 2.e. Take care of overfitting of decision tree model <br>
# Using Random Forest Classifier

# %%
rfc = RandomForestClassifier()
rfc.fit(X_transformed,y_transformed)
rfc_preds = rfc.predict(X_test)
metrics(y_test,rfc_preds)
rfc_f1 = f1_score(y_test, rfc_preds, average="macro")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# Model Accuracy Score:0.539117941993212
# Model Classification Report
#               precision    recall  f1-score   support
#
#            0       0.55      0.87      0.67     56993
#            1       0.46      0.14      0.21     46719
#
#     accuracy                           0.54    103712
#    macro avg       0.51      0.50      0.44    103712
# weighted avg       0.51      0.54      0.46    103712
#
# Confusion Matrix
# [[49597  7396]
#  [40403  6316]]

# %%
print(f'F1 Score - Random Forest Classifier:{rfc_f1}')
# Out:
# F1 Score - Random Forest Classifier:0.44192651915603004
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# 2.f. The final prediction will rely on the majority class voted by five models generated through the
# stratified five-fold method.

# %% [markdown]
# Using stratified K fold to balance the target variable - Logistic Regression

# %%
# instead of using scikit learn's pipeline, we import from imblearn
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
# just like we did for StandardScaler, we instantiate SMOTE within the pipeline
pipe = Pipeline(steps = [('smote', SMOTE(random_state = 42)),
                      ('standardscaler', StandardScaler()),
                      ('logisticregression', LogisticRegression())])
# cross validation using intra-fold sampling
skf = StratifiedKFold(n_splits=5)
scores_lreg = cross_val_score(pipe, X_train, y_train, cv=skf, scoring="accuracy",n_jobs=-1)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Using stratified K fold to balance the target variable - K-nearest Neighbours

# %%
from sklearn.neighbors import KNeighborsClassifier
# instead of using scikit learn's pipeline, we import from imblearn
# just like we did for StandardScaler, we instantiate SMOTE within the pipeline
pipe = Pipeline(steps = [('smote', SMOTE(random_state = 42)),
                      ('standardscaler', StandardScaler()),
                      ('knn', KNeighborsClassifier())])
# cross validation using intra-fold sampling
skf = StratifiedKFold(n_splits=5)
scores_knn = cross_val_score(pipe, X_train, y_train, cv=skf, scoring="accuracy",n_jobs=-1)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Using stratified K fold to balance the target variable - Shotastic Gradient Descend

# %%
# instead of using scikit learn's pipeline, we import from imblearn
# just like we did for StandardScaler, we instantiate SMOTE within the pipeline
pipe = Pipeline(steps = [('smote', SMOTE(random_state = 42)),
                      ('standardscaler', StandardScaler()),
                      ('sgd_model', SGDClassifier(loss='log_loss'))])
# cross validation using intra-fold sampling
skf = StratifiedKFold(n_splits=5)
scores_sgd = cross_val_score(pipe, X_train, y_train, cv=skf, scoring="accuracy",n_jobs=-1)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Using stratified K fold to balance the target variable - Decision Tree

# %%
# instead of using scikit learn's pipeline, we import from imblearn
# just like we did for StandardScaler, we instantiate SMOTE within the pipeline
pipe = Pipeline(steps = [('smote', SMOTE(random_state = 42)),
                      ('standardscaler', StandardScaler()),
                      ('desciontree', DecisionTreeClassifier())])
# cross validation using intra-fold sampling
skf = StratifiedKFold(n_splits=5)
scores_dtm = cross_val_score(pipe, X_train, y_train, cv=skf, scoring="accuracy",n_jobs=-1)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Using stratified K fold to balance the target variable - Random Forest

# %%
# instead of using scikit learn's pipeline, we import from imblearn
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
# just like we did for StandardScaler, we instantiate SMOTE within the pipeline
pipe = Pipeline(steps = [('smote', SMOTE(random_state = 42)),
                      ('standardscaler', StandardScaler()),
                      ('randomforest', RandomForestClassifier())])
# cross validation using intra-fold sampling
skf = StratifiedKFold(n_splits=5)
scores_rf = cross_val_score(pipe, X_train, y_train, cv=skf, scoring="accuracy",n_jobs=-1)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# 2.g. Compare the results of logistic regression and decision tree classifier

# %%
print('Accuracy Scores')
print(f'Cross Validation Score-Logistic Regression:{scores_lreg.mean()}')
print(f'Cross Validation Score-Knn Model:{scores_knn.mean()}')
print(f'Cross Validation Score-Shoctastic Gradient Descend:{scores_sgd.mean()}')
print(f'Cross Validation Score-Decison Tree:{scores_dtm.mean()}')
print(f'Cross Validation Score-Random Forest Classifier:{scores_rf.mean()}')
# Out:
# Accuracy Scores
# Cross Validation Score-Logistic Regression:0.5757248501556703
# Cross Validation Score-Knn Model:0.6117094687467388
# Cross Validation Score-Shoctastic Gradient Descend:0.5716220854166838
# Cross Validation Score-Decison Tree:0.605410712737622
# Cross Validation Score-Random Forest Classifier:0.6139777913783057
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# 3. Build and validate the models using the Gradient Boosting classifier, compare all methods, and share your findings

# %%
# just like we did for StandardScaler, we instantiate SMOTE within the pipeline
pipe = Pipeline(steps = [('smote', SMOTE(random_state = 42)),
                      ('standardscaler', StandardScaler()),
                      ('xgboost', XGBClassifier())])
# cross validation using intra-fold sampling
skf = StratifiedKFold(n_splits=5)
scores_xgb = cross_val_score(pipe, X_train, y_train, cv=skf, scoring="accuracy",n_jobs=-1)
print(f'Cross Validation Score-XGBoost Classifier:{scores_xgb.mean()}')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Cross Validation Score-XGBoost Classifier:0.658780171956631

# %% [markdown]
# XG boost gives a bettter average score between Logistic Regression,Knn, Decision Tree and Random Forest.
